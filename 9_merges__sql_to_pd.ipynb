# %% [markdown]
# <a href="https://colab.research.google.com/github/PhoenixCC0722/Journey_to_become_DataScientist/blob/main/9_merges__sql_to_pd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
import pandas as pd

# load data
# This code is made to load our data stored on Google Drive
def gd_path(file_id):
    """Generate a shareable link from Google Drive file id."""
    return f"https://drive.google.com/uc?export=download&id={file_id}"

# Google Drive file ids
files_id = {
    "titles": "1PLdn50N9GRa53ZbuVWo0l47F_IXdvlEm",
    "stores": "1f-GCgip7O93CpbAkYvOsc21eKnSOSHsQ",
    "sales": "1fzFc9rwYmVIPaGOFmhLVxCi3kg19vNU2",
    "publishers": "1s9E8_AVOziTrowb3wyh2jg3PV763VOyq",
    "pub_info": "1OEgogcGKy--EpuVj0kqq7lyBZNGW6YSv",
    "jobs": "1V1Za8hUdXD-vJOyRdX4aQV5wanIff2eM",
    "employee": "1h9mUjsVqpP74b1w0x7KOw37n_n9Ulkt5",
    "discounts": "111dvSxMcCsTgOuV1wDSKFJxO1Xcxd9VS",
}

# Read data from Google Drive
sales = pd.read_csv(gd_path(files_id["sales"]), sep=";")
titles = pd.read_csv(gd_path(files_id["titles"]), sep=";")
employee = pd.read_csv(gd_path(files_id["employee"]), sep=";")
stores = pd.read_csv(gd_path(files_id["stores"]), sep=";")
publishers = pd.read_csv(gd_path(files_id["publishers"]), sep=";")
# Replace the logos pandas can't read with '?'
pub_info = pd.read_csv(gd_path(files_id["pub_info"]), sep=";", encoding_errors = 'replace')
discounts = pd.read_csv(gd_path(files_id["discounts"]), sep=";")
jobs = pd.read_csv(gd_path(files_id["jobs"]), sep=";")

# %% [markdown]
# # From SQL to pandas challenge 9

# %% [markdown]
# ##  1.&nbsp;Select the table sales, assigning the alias "s" to it.
#    Select the column ord_num using the syntax `table_alias[column]`

# %%
df_sales = pd.DataFrame(sales)
df_sales = df_sales.rename(columns={'ord_num':'s'})
df_sales
# Out:
#     stor_id         s             ord_date  qty    payterms title_id
# 0      6380      6871  1994-09-14 00:00:00    5      Net 60   BU1032
# 1      6380      722a  1994-09-13 00:00:00    3      Net 60   PS2091
# 2      7066     A2976  1993-05-24 00:00:00   50      Net 30   PC8888
# 3      7066  QA7442.3  1994-09-13 00:00:00   75  ON invoice   PS2091
# 4      7067     D4482  1994-09-14 00:00:00   10      Net 60   PS2091
# 5      7067     P2121  1992-06-15 00:00:00   40      Net 30   TC3218
# 6      7067     P2121  1992-06-15 00:00:00   20      Net 30   TC4203
# 7      7067     P2121  1992-06-15 00:00:00   20      Net 30   TC7777
# 8      7131   N914008  1994-09-14 00:00:00   20      Net 30   PS2091
# 9      7131   N914014  1994-09-14 00:00:00   25      Net 30   MC3021
# 10     7131    P3087a  1993-05-29 00:00:00   20      Net 60   PS1372
# 11     7131    P3087a  1993-05-29 00:00:00   25      Net 60   PS2106
# 12     7131    P3087a  1993-05-29 00:00:00   15      Net 60   PS3333
# 13     7131    P3087a  1993-05-29 00:00:00   25      Net 60   PS7777
# 14     7896    QQ2299  1993-10-28 00:00:00   15      Net 60   BU7832
# 15     7896     TQ456  1993-12-12 00:00:00   10      Net 60   MC2222
# 16     7896      X999  1993-02-21 00:00:00   35  ON invoice   BU2075
# 17     8042  423LL922  1994-09-14 00:00:00   15  ON invoice   MC3021
# 18     8042  423LL930  1994-09-14 00:00:00   10  ON invoice   BU1032
# 19     8042      P723  1993-03-11 00:00:00   25      Net 30   BU1111
# 20     8042   QA879.1  1993-05-22 00:00:00   30      Net 30   PC1035

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT s.ord_num
# FROM sales AS s;
# ```

# %% [markdown]
# ## 2.&nbsp;Select the title and publisher name of all books

# %%
df_title = pd.DataFrame(titles)
df_title.head()
# Out:
#   title_id                                              title      type  \
# 0   BU1032                The Busy Executive's Database Guide  business
# 1   BU1111  Cooking with Computers: Surreptitious Balance ...  business
# 2   BU2075                    You Can Combat Computer Stress!  business
# 3   BU7832                      Straight Talk About Computers  business
# 4   MC2222                  Silicon Valley Gastronomic Treats  mod_cook
#
#    pub_id  price  advance  royalty  ytd_sales  \
# 0    1389  19.99   5000.0       10       4095
# 1    1389  11.95   5000.0       10       3876
# 2     736   2.99  10125.0       24      18722
# 3    1389  19.99   5000.0       10       4095
# 4     877  19.99      0.0       12       2032
#
#                                                notes              pubdate
# 0  An overview of available database systems with...  1991-06-12 00:00:00
# 1  Helpful hints on how to use your electronic re...  1991-06-09 00:00:00
# 2  The latest medical and psychological technique...  1991-06-30 00:00:00
# 3  Annotated analysis of what computers can do fo...  1991-06-22 00:00:00
# 4  Favorite recipes for quick, easy, and elegant ...  1991-06-09 00:00:00

# %%
df_publisher = pd.DataFrame(publishers)
df_publisher.head()
# Out:
#    pub_id               pub_name        city state country
# 0     736         New Moon Books      Boston    MA     USA
# 1     877       Binnet & Hardley  Washington    DC     USA
# 2    1389   Algodata Infosystems    Berkeley    CA     USA
# 3    1622  Five Lakes Publishing     Chicago    IL     USA
# 4    1756      Ramona Publishers      Dallas    TX     USA

# %%
df_m = df_title.merge(df_publisher,on='pub_id')
df_m[['title','pub_name']].head(20)
# Out:
#                                                 title              pub_name
# 0                 The Busy Executive's Database Guide  Algodata Infosystems
# 1   Cooking with Computers: Surreptitious Balance ...  Algodata Infosystems
# 2                       Straight Talk About Computers  Algodata Infosystems
# 3                            But Is It User Friendly?  Algodata Infosystems
# 4                           Secrets of Silicon Valley  Algodata Infosystems
# 5                                       Net Etiquette  Algodata Infosystems
# 6                     You Can Combat Computer Stress!        New Moon Books
# 7                                 Is Anger the Enemy?        New Moon Books
# 8                                   Life Without Fear        New Moon Books
# 9       Prolonged Data Deprivation: Four Case Studies        New Moon Books
# 10                Emotional Security: A New Algorithm        New Moon Books
# 11                  Silicon Valley Gastronomic Treats      Binnet & Hardley
# 12                              The Gourmet Microwave      Binnet & Hardley
# 13                 The Psychology of Computer Cooking      Binnet & Hardley
# 14  Computer Phobic AND Non-Phobic Individuals: Be...      Binnet & Hardley
# 15  Onions, Leeks, and Garlic: Cooking Secrets of ...      Binnet & Hardley
# 16          Fifty Years in Buckingham Palace Kitchens      Binnet & Hardley
# 17                                     Sushi, Anyone?      Binnet & Hardley

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT t.title, p.pub_name
# FROM titles t
# LEFT JOIN publishers p ON t.pub_id = p.pub_id;
# ```

# %% [markdown]
# ## 3.&nbsp;Select the order number, quantity and book title for all sales.

# %%
df_sales = pd.DataFrame(sales)
df_sales.head()
# Out:
#    stor_id   ord_num             ord_date  qty    payterms title_id
# 0     6380      6871  1994-09-14 00:00:00    5      Net 60   BU1032
# 1     6380      722a  1994-09-13 00:00:00    3      Net 60   PS2091
# 2     7066     A2976  1993-05-24 00:00:00   50      Net 30   PC8888
# 3     7066  QA7442.3  1994-09-13 00:00:00   75  ON invoice   PS2091
# 4     7067     D4482  1994-09-14 00:00:00   10      Net 60   PS2091

# %%
df_title.head()
# Out:
#   title_id                                              title      type  \
# 0   BU1032                The Busy Executive's Database Guide  business
# 1   BU1111  Cooking with Computers: Surreptitious Balance ...  business
# 2   BU2075                    You Can Combat Computer Stress!  business
# 3   BU7832                      Straight Talk About Computers  business
# 4   MC2222                  Silicon Valley Gastronomic Treats  mod_cook
#
#    pub_id  price  advance  royalty  ytd_sales  \
# 0    1389  19.99   5000.0       10       4095
# 1    1389  11.95   5000.0       10       3876
# 2     736   2.99  10125.0       24      18722
# 3    1389  19.99   5000.0       10       4095
# 4     877  19.99      0.0       12       2032
#
#                                                notes              pubdate
# 0  An overview of available database systems with...  1991-06-12 00:00:00
# 1  Helpful hints on how to use your electronic re...  1991-06-09 00:00:00
# 2  The latest medical and psychological technique...  1991-06-30 00:00:00
# 3  Annotated analysis of what computers can do fo...  1991-06-22 00:00:00
# 4  Favorite recipes for quick, easy, and elegant ...  1991-06-09 00:00:00

# %%
df_m = df_sales.merge(df_title, on='title_id')
df_m[['ord_num','qty','title']].head(20)
# Out:
#      ord_num  qty                                              title
# 0       6871    5                The Busy Executive's Database Guide
# 1   423LL930   10                The Busy Executive's Database Guide
# 2       722a    3                                Is Anger the Enemy?
# 3   QA7442.3   75                                Is Anger the Enemy?
# 4      D4482   10                                Is Anger the Enemy?
# 5    N914008   20                                Is Anger the Enemy?
# 6      A2976   50                          Secrets of Silicon Valley
# 7      P2121   40  Onions, Leeks, and Garlic: Cooking Secrets of ...
# 8      P2121   20          Fifty Years in Buckingham Palace Kitchens
# 9      P2121   20                                     Sushi, Anyone?
# 10   N914014   25                              The Gourmet Microwave
# 11  423LL922   15                              The Gourmet Microwave
# 12    P3087a   20  Computer Phobic AND Non-Phobic Individuals: Be...
# 13    P3087a   25                                  Life Without Fear
# 14    P3087a   15      Prolonged Data Deprivation: Four Case Studies
# 15    P3087a   25                Emotional Security: A New Algorithm
# 16    QQ2299   15                      Straight Talk About Computers
# 17     TQ456   10                  Silicon Valley Gastronomic Treats
# 18      X999   35                    You Can Combat Computer Stress!
# 19      P723   25  Cooking with Computers: Surreptitious Balance ...

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT ord_num, qty, titles.title
# FROM sales
# LEFT JOIN titles
# ON sales.title_id=titles.title_id;
# ```

# %% [markdown]
# ## 4.&nbsp;Select the full name of all employees and the name of the publisher they work for

# %%
df_publisher = pd.DataFrame(publishers)
df_publisher.head()
# Out:
#    pub_id               pub_name        city state country
# 0     736         New Moon Books      Boston    MA     USA
# 1     877       Binnet & Hardley  Washington    DC     USA
# 2    1389   Algodata Infosystems    Berkeley    CA     USA
# 3    1622  Five Lakes Publishing     Chicago    IL     USA
# 4    1756      Ramona Publishers      Dallas    TX     USA

# %%
df_employee = pd.DataFrame(employee)
df_employee.head()
# Out:
#       emp_id    fname minit      lname  job_id  job_lvl  pub_id  \
# 0  A-C71970F     Aria   NaN       Cruz      10       87    1389
# 1  A-R89858F  Annette   NaN     Roulet       6      152    9999
# 2  AMD15433F      Ann     M      Devon       3      200    9952
# 3  ARD36773F  Anabela     R  Domingues       8      100     877
# 4  CFH28514M   Carlos     F   Hernadez       5      211    9999
#
#              hire_date
# 0  1991-10-26 00:00:00
# 1  1990-02-21 00:00:00
# 2  1991-07-16 00:00:00
# 3  1993-01-27 00:00:00
# 4  1989-04-21 00:00:00

# %%
df_m = df_employee.merge(df_publisher,on='pub_id')
df_m[['fname','lname','pub_name']].head(20)
# Out:
#         fname      lname              pub_name
# 0        Aria       Cruz  Algodata Infosystems
# 1      Carine    Schmitt  Algodata Infosystems
# 2       Diego       Roel  Algodata Infosystems
# 3       Maria    Larsson  Algodata Infosystems
# 4      Miguel    Paolino  Algodata Infosystems
# 5    Margaret      Smith  Algodata Infosystems
# 6       Pedro     Afonso  Algodata Infosystems
# 7       Paula    Parente  Algodata Infosystems
# 8        Sven    Ottlieb  Algodata Infosystems
# 9       Yoshi    Latimer  Algodata Infosystems
# 10    Annette     Roulet    Lucerne Publishing
# 11     Carlos   Hernadez    Lucerne Publishing
# 12  Helvetius       Nagy    Lucerne Publishing
# 13      Karla  Jablonski    Lucerne Publishing
# 14     Manuel    Pereira    Lucerne Publishing
# 15   Patricia    McKenna    Lucerne Publishing
# 16     Pirkko  Koskitalo    Lucerne Publishing
# 17        Ann      Devon        Scootney Books
# 18  Francisco      Chang        Scootney Books
# 19     Philip     Cramer        Scootney Books

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# Select E.fname,E.lname,P.pub_name
# from employee E
# left join publishers P
# on E.pub_id=P.pub_id;
# ```

# %% [markdown]
# ## 5.&nbsp;Select the full name and job description of all employees.

# %%
df_employee = pd.DataFrame(employee)
df_employee.head()
# Out:
#       emp_id    fname minit      lname  job_id  job_lvl  pub_id  \
# 0  A-C71970F     Aria   NaN       Cruz      10       87    1389
# 1  A-R89858F  Annette   NaN     Roulet       6      152    9999
# 2  AMD15433F      Ann     M      Devon       3      200    9952
# 3  ARD36773F  Anabela     R  Domingues       8      100     877
# 4  CFH28514M   Carlos     F   Hernadez       5      211    9999
#
#              hire_date
# 0  1991-10-26 00:00:00
# 1  1990-02-21 00:00:00
# 2  1991-07-16 00:00:00
# 3  1993-01-27 00:00:00
# 4  1989-04-21 00:00:00

# %%
df_jobs = pd.DataFrame(jobs)
df_jobs.head()
# Out:
#    job_id                      job_desc  min_lvl  max_lvl
# 0       1  New Hire - Job not specified       10       10
# 1       2       Chief Executive Officer      200      250
# 2       3   Business Operations Manager      175      225
# 3       4      Chief Financial Officier      175      250
# 4       5                     Publisher      150      250

# %%
df_m = df_employee.merge(df_jobs, on='job_id')
df_m[['fname','lname','job_desc']].head()
# Out:
#      fname      lname             job_desc
# 0     Aria       Cruz  Productions Manager
# 1   Martin     Sommer  Productions Manager
# 2    Peter    Franken  Productions Manager
# 3   Pirkko  Koskitalo  Productions Manager
# 4  Annette     Roulet      Managing Editor

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT fname, lname, job_desc
# FROM employee
# LEFT JOIN jobs
# ON employee.job_id = jobs.job_id;
# ```

# %% [markdown]
# ## 6.&nbsp;Select the full name, job description and publisher name of all employees
#    Hint: you will have to perform 2 joins in a single query to merge 3 tables together.

# %%
df_employee = pd.DataFrame(employee)
df_publisher = pd.DataFrame(publishers)
df_jobs = pd.DataFrame(jobs)
df_m1 = df_employee.merge(df_publisher, on='pub_id')
df_m2 = df_m1.merge(df_jobs, on='job_id')
df_m2[['fname','lname','job_desc','pub_name']].head()
# Out:
#     fname      lname              job_desc              pub_name
# 0    Aria       Cruz   Productions Manager  Algodata Infosystems
# 1  Pirkko  Koskitalo   Productions Manager    Lucerne Publishing
# 2   Peter    Franken   Productions Manager      Binnet & Hardley
# 3  Martin     Sommer   Productions Manager        New Moon Books
# 4  Carine    Schmitt  Sales Representative  Algodata Infosystems

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT fname, lname, job_desc, pub_name
# FROM employee
# LEFT JOIN publishers
# ON employee.pub_id = publishers.pub_id
# LEFT JOIN jobs
# ON employee.job_id = jobs.job_id;
# ```

# %% [markdown]
# ## 7.&nbsp;Select the full name, job description and publisher name of employees that work for Binnet & Hardley.

# %%
# set up a filter 'work for Binnet and Hardley', in publisher DataFrame
df_publisher.head()
# Out:
#    pub_id               pub_name        city state country
# 0     736         New Moon Books      Boston    MA     USA
# 1     877       Binnet & Hardley  Washington    DC     USA
# 2    1389   Algodata Infosystems    Berkeley    CA     USA
# 3    1622  Five Lakes Publishing     Chicago    IL     USA
# 4    1756      Ramona Publishers      Dallas    TX     USA

# %%
df_employee = pd.DataFrame(employee)
df_publisher = pd.DataFrame(publishers)
df_jobs = pd.DataFrame(jobs)
df_m1 = df_employee.merge(df_publisher, on='pub_id')
df_m2 = df_m1.merge(df_jobs, on='job_id')
df_m2.loc[(df_m2['pub_name'] == 'Binnet & Hardley'), ['fname','lname','job_desc','pub_name']]
# Out:
#         fname      lname                  job_desc          pub_name
# 2       Peter    Franken       Productions Manager  Binnet & Hardley
# 5       Paolo    Accorti      Sales Representative  Binnet & Hardley
# 9    Victoria   Ashworth           Managing Editor  Binnet & Hardley
# 13     Lesley      Brown         Marketing Manager  Binnet & Hardley
# 17     Daniel     Tonini        Operations Manager  Binnet & Hardley
# 21    Martine      Rance      Acquisitions Manager  Binnet & Hardley
# 24  Elizabeth    Lincoln                  Designer  Binnet & Hardley
# 28    Anabela  Domingues  Public Relations Manager  Binnet & Hardley
# 32       Paul    Henriot                 Publisher  Binnet & Hardley
# 38      Helen    Bennett                    Editor  Binnet & Hardley

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT fname, lname, job_desc, pub_name
# FROM employee
# LEFT JOIN publishers
# ON employee.pub_id=publishers.pub_id
# LEFT JOIN jobs
# ON employee.job_id=jobs.job_id
# WHERE pub_name='Binnet & Hardley';
# ```

# %% [markdown]
# ## 8.&nbsp;Select the name and PR Info (from the pub_info table) from all publishers based in Berkeley, California.

# %%
df_pub_info =  pd.DataFrame(pub_info)
df_pub_info.head()
df_publisher.head()
# Out:
#    pub_id               pub_name        city state country
# 0     736         New Moon Books      Boston    MA     USA
# 1     877       Binnet & Hardley  Washington    DC     USA
# 2    1389   Algodata Infosystems    Berkeley    CA     USA
# 3    1622  Five Lakes Publishing     Chicago    IL     USA
# 4    1756      Ramona Publishers      Dallas    TX     USA

# %%
df_m = df_publisher.merge(df_pub_info, on='pub_id')
df_m.loc[((df_m['city'] == 'Berkeley')&(df_m['state'] == 'CA')),['pub_name','pr_info']]
# Out:
#                pub_name                                            pr_info
# 2  Algodata Infosystems  This is sample text data for Algodata Infosyst...

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# select pub_name, pub_info.pr_info
# from publishers
# left join pub_info
# on pub_info.pub_id = publishers.pub_id
# where city in ("Berkeley") and state='CA';
#
# ```

# %% [markdown]
# ## 9.&nbsp;Selet all columns from the discounts table.
#    Observe the columns it has and now some of them are filled with NULL values.

# %%
df_discounts = pd.DataFrame(discounts)
df_discounts[['stor_id']]
df_discounts
# Out:
#         discounttype  stor_id  lowqty  highqty  discount
# 0   Initial Customer      NaN       0        0      10.5
# 1    Volume Discount      NaN     100     1000       6.7
# 2  Customer Discount   8042.0       0        0       5.0

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT * FROM discounts;
# ```

# %% [markdown]
# ## 10.&nbsp;Select all store names, their store id and the discounts they offer.
#
# 	   - When selecting the store id, select it two times: from the stores table
#          and from the discounts table.
#
#        - ALL stores should be displayed, even if they don't offer any discount
#          (i.e. have a NULL value on the discount column).

# %%
df_stores = pd.DataFrame(stores)
df_stores.head()
df_stores[['stor_id']]
# Out:
#    stor_id
# 0     6380
# 1     7066
# 2     7067
# 3     7131
# 4     7896
# 5     8042

# %%
df_m = df_discounts.merge(stores, how='right', left_on='stor_id', right_on='stor_id', suffixes=('_left', '_right'))
df_m[['stor_id','discount','stor_name']]
# Out:
#    stor_id  discount                             stor_name
# 0   6380.0       NaN                   Eric the Read Books
# 1   7066.0       NaN                              Barnum's
# 2   7067.0       NaN                          News & Brews
# 3   7131.0       NaN  Doc-U-Mat: Quality Laundry and Books
# 4   7896.0       NaN                    Fricative Bookshop
# 5   8042.0       5.0                              Bookbeat

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT d.stor_id AS disstor, d.discount, s.stor_id AS storid, s.stor_name
# FROM discounts AS d
# RIGHT JOIN stores AS s
# ON d.stor_id=s.stor_id;
#
# ```

# %% [markdown]
# ## 11.&nbsp;Select all store names and the discounts they offer.
#
#        - This time, we don't want do display stores that don't offer any
#          discount.
#
#     Hint: change the join type!

# %%
df_m = df_discounts.merge(stores, how='inner', left_on='stor_id', right_on='stor_id', suffixes=('_left', '_right'))
df_m[['stor_id','discount','stor_name']]
# Out:
#    stor_id  discount stor_name
# 0   8042.0       5.0  Bookbeat

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# select St.stor_name,St.stor_id ,D.discount
# from  stores St
# inner join discounts  D on St.stor_id=D.stor_id ;
# ```
