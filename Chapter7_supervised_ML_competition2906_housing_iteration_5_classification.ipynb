# %% [markdown]
# <a href="https://colab.research.google.com/github/PhoenixCC0722/Journey_to_become_DataScientist/blob/main/Chapter7_supervised_ML_competition2906_housing_iteration_5_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Competition of Supervised ML for the housing data**

# %% [markdown]
# *   Dataset: We'll be using the housing dataset available on our learning platform. Find it here 👉🏽 https://learn.wbscodingschool.com/courses/data-science/lessons/🏗-3-ml-classification/topic/📝-iteration-5-model-selection/.
# *   Goal: Practice all day to craft the best scoring model.
# *   Challenge: Once you've perfected your model, put it to the test with the unseen data attached to this post.
# *   Submission: Should be done here https://bestpricehouse.streamlit.app/ Make sure you have the correct format for the submission .csv

# %% [markdown]
# ### **Step 1. Data reading & splitting**

# %%
# required packages
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %% [markdown]
# >> How to get the url and the **correct path** of the .csv file
#
# -- download the dataset from the Learning Platform
#
# -- upload the .csv filt to Google Drive
#
# -- find the file on the Google Drive website and the choose 'open with Google sheet'
#
# !!! how to set the "share" --> anyone on the internet with the link can open it (bcz default is only me can read it)

# %%
# 1st way
url = "https://drive.google.com/file/d/19bkrhj__h0cEKgpjc-DXcNhF2A30UKhI/view?usp=sharing" # the .csv file is already uploaded from local server to the colad in google drive. In colab notebook, 'share' --> anyone with the link --> 'copy the link'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]

data = pd.read_csv(path)
data.columns
# Out:
# Index(['LotArea', 'LotFrontage', 'TotalBsmtSF', 'BedroomAbvGr', 'Fireplaces',
#        'PoolArea', 'GarageCars', 'WoodDeckSF', 'ScreenPorch', 'Expensive',
#        'MSZoning', 'Condition1', 'Heating', 'Street', 'CentralAir',
#        'Foundation', 'ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'KitchenQual', 'FireplaceQu',
#        'MSSubClass', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath',
#        'FullBath', 'HalfBath', 'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageYrBlt',
#        'GarageArea', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'MiscVal',
#        'MoSold', 'YrSold', 'Id', 'Alley', 'LotShape', 'LandContour',
#        'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'BsmtFinType2', 'HeatingQC', 'Electrical',
#        'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType',
#        'SaleCondition'],
#       dtype='object')

# %%
# 2nd way
# Get the spreadsheet ID and name
# google sheets address: https://docs.google.com/spreadsheets/d/1Y5iy40vxJ8QCXpgz4O4UOUhJ3Fx6chj4Bkp0h4mJx_c/edit?gid=1175286409#gid=1175286409
sheet_id = "1Y5iy40vxJ8QCXpgz4O4UOUhJ3Fx6chj4Bkp0h4mJx_c"
sheet_name = "1175286409"

# Construct the URL to the CSV export of the spreadsheet
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv&gid={sheet_name}"

# Read the CSV data into a Pandas DataFrame
data = pd.read_csv(url)
data.columns
# Out:
# Index(['LotArea', 'LotFrontage', 'TotalBsmtSF', 'BedroomAbvGr', 'Fireplaces',
#        'PoolArea', 'GarageCars', 'WoodDeckSF', 'ScreenPorch', 'Expensive',
#        'MSZoning', 'Condition1', 'Heating', 'Street', 'CentralAir',
#        'Foundation', 'ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'KitchenQual', 'FireplaceQu',
#        'MSSubClass', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath',
#        'FullBath', 'HalfBath', 'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageYrBlt',
#        'GarageArea', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'MiscVal',
#        'MoSold', 'YrSold', 'Id', 'Alley', 'LotShape', 'LandContour',
#        'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'BsmtFinType2', 'HeatingQC', 'Electrical',
#        'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType',
#        'SaleCondition'],
#       dtype='object')

# %%
data.dtypes
# Out:
# LotArea            int64
# LotFrontage      float64
# TotalBsmtSF        int64
# BedroomAbvGr       int64
# Fireplaces         int64
#                   ...
# PoolQC            object
# Fence             object
# MiscFeature       object
# SaleType          object
# SaleCondition     object
# Length: 81, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   LotArea        1460 non-null   int64
#  1   LotFrontage    1201 non-null   float64
#  2   TotalBsmtSF    1460 non-null   int64
#  3   BedroomAbvGr   1460 non-null   int64
#  4   Fireplaces     1460 non-null   int64
#  5   PoolArea       1460 non-null   int64
#  6   GarageCars     1460 non-null   int64
#  7   WoodDeckSF     1460 non-null   int64
#  8   ScreenPorch    1460 non-null   int64
#  9   Expensive      1460 non-null   int64
#  10  MSZoning       1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Heating        1460 non-null   object
#  13  Street         1460 non-null   object
#  14  CentralAir     1460 non-null   object
#  15  Foundation     1460 non-null   object
#  16  ExterQual      1460 non-null   object
#  17  ExterCond      1460 non-null   object
#  18  BsmtQual       1423 non-null   object
#  19  BsmtCond       1423 non-null   object
#  20  BsmtExposure   1422 non-null   object
#  21  BsmtFinType1   1423 non-null   object
#  22  KitchenQual    1460 non-null   object
#  23  FireplaceQu    770 non-null    object
#  24  MSSubClass     1460 non-null   int64
#  25  OverallQual    1460 non-null   int64
#  26  OverallCond    1460 non-null   int64
#  27  YearBuilt      1460 non-null   int64
#  28  YearRemodAdd   1460 non-null   int64
#  29  MasVnrArea     1452 non-null   float64
#  30  BsmtFinSF1     1460 non-null   int64
#  31  BsmtFinSF2     1460 non-null   int64
#  32  BsmtUnfSF      1460 non-null   int64
#  33  1stFlrSF       1460 non-null   int64
#  34  2ndFlrSF       1460 non-null   int64
#  35  LowQualFinSF   1460 non-null   int64
#  36  GrLivArea      1460 non-null   int64
#  37  BsmtFullBath   1460 non-null   int64
#  38  BsmtHalfBath   1460 non-null   int64
#  39  FullBath       1460 non-null   int64
#  40  HalfBath       1460 non-null   int64
#  41  KitchenAbvGr   1460 non-null   int64
#  42  TotRmsAbvGrd   1460 non-null   int64
#  43  GarageYrBlt    1379 non-null   float64
#  44  GarageArea     1460 non-null   int64
#  45  OpenPorchSF    1460 non-null   int64
#  46  EnclosedPorch  1460 non-null   int64
#  47  3SsnPorch      1460 non-null   int64
#  48  MiscVal        1460 non-null   int64
#  49  MoSold         1460 non-null   int64
#  50  YrSold         1460 non-null   int64
#  51  Id             1460 non-null   int64
#  52  Alley          91 non-null     object
#  53  LotShape       1460 non-null   object
#  54  LandContour    1460 non-null   object
#  55  Utilities      1460 non-null   object
#  56  LotConfig      1460 non-null   object
#  57  LandSlope      1460 non-null   object
#  58  Neighborhood   1460 non-null   object
#  59  Condition2     1460 non-null   object
#  60  BldgType       1460 non-null   object
#  61  HouseStyle     1460 non-null   object
#  62  RoofStyle      1460 non-null   object
#  63  RoofMatl       1460 non-null   object
#  64  Exterior1st    1460 non-null   object
#  65  Exterior2nd    1460 non-null   object
#  66  MasVnrType     588 non-null    object
#  67  BsmtFinType2   1422 non-null   object
#  68  HeatingQC      1460 non-null   object
#  69  Electrical     1459 non-null   object
#  70  Functional     1460 non-null   object
#  71  GarageType     1379 non-null   object
#  72  GarageFinish   1379 non-null   object
#  73  GarageQual     1379 non-null   object
#  74  GarageCond     1379 non-null   object
#  75  PavedDrive     1460 non-null   object
#  76  PoolQC         7 non-null      object
#  77  Fence          281 non-null    object
#  78  MiscFeature    54 non-null     object
#  79  SaleType       1460 non-null   object
#  80  SaleCondition  1460 non-null   object
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
# X (feature vectors) and y (label/target) creation
X = data
y = X.pop("Expensive")

# data splitting
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# building the pipeline
X_cat = X.select_dtypes(exclude="number").copy()
X_num = X.select_dtypes(include="number").copy()

numeric_pipe = make_pipeline(
    SimpleImputer(strategy="mean"))

categoric_pipe = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="N_A"),
    OneHotEncoder(handle_unknown="ignore")
)

preprocessor = ColumnTransformer(
    transformers=[
        ("num_pipe", numeric_pipe, X_num.columns),
        ("cat_pipe", categoric_pipe, X_cat.columns),
    ]
)

# %%
X_test.tail(20)
# Out:
#       LotArea  LotFrontage  TotalBsmtSF  BedroomAbvGr  Fireplaces  PoolArea  \
# 1203     9750         75.0         1630             3           1         0
# 163      5500         55.0          882             1           0         0
# 270     10728         84.0         1095             3           1         0
# 33      10552         70.0         1398             4           1         0
# 385      3182         43.0         1256             2           1         0
# 929     13006          NaN          964             4           1         0
# 966      9600        130.0          728             2           2         0
# 427      8593         77.0          907             3           0         0
# 873     12144         60.0          832             3           1         0
# 486     10289         79.0         1073             3           0         0
# 646      7200         60.0            0             3           0         0
# 996     10659          NaN         1050             3           0         0
# 623      2117          NaN          756             2           1         0
# 1028     9492         79.0          768             3           1         0
# 1108     8063          NaN          924             3           1         0
# 1012    10592         55.0          602             3           2         0
# 1059    11275          NaN          854             3           1         0
# 890      8064         60.0          672             3           1         0
# 628     11606         70.0         1040             5           2         0
# 352      9084         60.0          616             3           0         0
#
#       GarageCars  WoodDeckSF  ScreenPorch MSZoning  ... GarageType  \
# 1203           2          74            0       RL  ...     Attchd
# 163            0           0            0       RL  ...        NaN
# 270            3         192            0       FV  ...     Attchd
# 33             2           0            0       RL  ...     Attchd
# 385            2         146          144       RL  ...     Attchd
# 929            2           0            0       RL  ...    BuiltIn
# 966            1           0            0       RL  ...     Detchd
# 427            1           0            0       RL  ...     Detchd
# 873            1           0            0       RL  ...     Attchd
# 486            2           0            0       RL  ...     Attchd
# 646            2           0            0       RL  ...     Detchd
# 996            1           0            0       RL  ...     Attchd
# 623            2           0            0       FV  ...     Detchd
# 1028           1           0            0       RL  ...     Attchd
# 1108           2         100            0       RL  ...     Attchd
# 1012           1          96           53       RL  ...     Detchd
# 1059           2           0            0       RL  ...     Detchd
# 890            2           0            0       RL  ...     Detchd
# 628            2         335            0       RL  ...     Attchd
# 352            1          48            0       RL  ...     Detchd
#
#      GarageFinish GarageQual GarageCond PavedDrive PoolQC  Fence MiscFeature  \
# 1203          Unf         TA         TA          Y    NaN    NaN         NaN
# 163           NaN        NaN        NaN          Y    NaN  MnPrv         NaN
# 270           RFn         TA         TA          Y    NaN    NaN         NaN
# 33            RFn         TA         TA          Y    NaN    NaN         NaN
# 385           Fin         TA         TA          Y    NaN    NaN         NaN
# 929           Fin         TA         TA          Y    NaN    NaN         NaN
# 966           Unf         TA         TA          Y    NaN    NaN         NaN
# 427           Unf         TA         TA          Y    NaN    NaN         NaN
# 873           Unf         TA         TA          Y    NaN    NaN        Othr
# 486           RFn         TA         TA          Y    NaN    NaN         NaN
# 646           Unf         TA         TA          Y    NaN    NaN         NaN
# 996           Unf         TA         TA          Y    NaN    NaN         NaN
# 623           Unf         TA         TA          Y    NaN    NaN         NaN
# 1028          Unf         TA         TA          Y    NaN    NaN         NaN
# 1108          RFn         TA         TA          Y    NaN    NaN         NaN
# 1012          Unf         TA         TA          Y    NaN    NaN         NaN
# 1059          Unf         TA         Fa          Y    NaN    NaN         NaN
# 890           Unf         TA         TA          Y    NaN  MnPrv        Shed
# 628           Unf         TA         TA          Y    NaN    NaN         NaN
# 352           Unf         TA         Fa          Y    NaN    NaN         NaN
#
#      SaleType SaleCondition
# 1203       WD        Normal
# 163        WD        Normal
# 270       New       Partial
# 33         WD        Normal
# 385        WD        Normal
# 929        WD        Normal
# 966        WD        Normal
# 427        WD        Normal
# 873        WD        Normal
# 486        WD        Normal
# 646        WD        Normal
# 996       COD        Normal
# 623        WD        Normal
# 1028       WD        Normal
# 1108       WD       Abnorml
# 1012       WD        Normal
# 1059       WD        Normal
# 890        WD        Normal
# 628        WD        Family
# 352     ConLw        Normal
#
# [20 rows x 80 columns]

# %% [markdown]
# ### **Step 2-1. Modelling (Decision Tree)**

# %%
from sklearn.model_selection import GridSearchCV

full_pipeline = make_pipeline(preprocessor,
                              DecisionTreeClassifier())

param_grid = {
    "columntransformer__num_pipe__simpleimputer__strategy":["mean", "median"],
    "decisiontreeclassifier__max_depth": range(2, 14, 2),
    "decisiontreeclassifier__min_samples_leaf": range(3, 12, 2)
}

model_dtree = GridSearchCV(full_pipeline,
                      param_grid,
                      cv=5,
                      verbose=1)

model_dtree.fit(X_train, y_train)

scores = {"dtree" : model_dtree.best_score_}

scores
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# {'dtree': 0.9289314405194233}

# %% [markdown]
# >> show the accuracy value of the 60 candidates and print the best fitting parameters
#
# -- create anempty list to store the accuracy values
#
# -- best_params

# %%
# Create a list to store the results
results = []

# Iterate through the parameter combinations
for params in model_dtree.cv_results_['params']:
    # Find the score for the corresponding combination
    score = model_dtree.cv_results_['mean_test_score'][model_dtree.cv_results_['params'].index(params)]

    # Append the combination and score to the results list
    results.append([params, score])

# Create a Pandas DataFrame from the results
results_df = pd.DataFrame(results, columns=['Parameters', 'Score'])

# Print the table
print(results_df)

# Get the best parameters
best_params = model_dtree.best_params_
print("\nBest KNeighborsClassifier Parameters:")
for param_name, param_value in best_params.items():
    print(f"{param_name}: {param_value}")

# Get the score of the best parameters
best_score = model_dtree.best_score_
print(f"\nBest Score: {best_score}")
# Out:
#                                            Parameters     Score
# 0   {'columntransformer__num_pipe__simpleimputer__...  0.917820
# 1   {'columntransformer__num_pipe__simpleimputer__...  0.917820
# 2   {'columntransformer__num_pipe__simpleimputer__...  0.917820
# 3   {'columntransformer__num_pipe__simpleimputer__...  0.917820
# 4   {'columntransformer__num_pipe__simpleimputer__...  0.917820
# 5   {'columntransformer__num_pipe__simpleimputer__...  0.922949
# 6   {'columntransformer__num_pipe__simpleimputer__...  0.925509
# 7   {'columntransformer__num_pipe__simpleimputer__...  0.917813
# 8   {'columntransformer__num_pipe__simpleimputer__...  0.920388
# 9   {'columntransformer__num_pipe__simpleimputer__...  0.926382
# 10  {'columntransformer__num_pipe__simpleimputer__...  0.918657
# 11  {'columntransformer__num_pipe__simpleimputer__...  0.928931
# 12  {'columntransformer__num_pipe__simpleimputer__...  0.925502
# 13  {'columntransformer__num_pipe__simpleimputer__...  0.917824
# 14  {'columntransformer__num_pipe__simpleimputer__...  0.924673
# 15  {'columntransformer__num_pipe__simpleimputer__...  0.918642
# 16  {'columntransformer__num_pipe__simpleimputer__...  0.924647
# 17  {'columntransformer__num_pipe__simpleimputer__...  0.923781
# 18  {'columntransformer__num_pipe__simpleimputer__...  0.922956
# 19  {'columntransformer__num_pipe__simpleimputer__...  0.926386
# 20  {'columntransformer__num_pipe__simpleimputer__...  0.916060
# 21  {'columntransformer__num_pipe__simpleimputer__...  0.921228
# 22  {'columntransformer__num_pipe__simpleimputer__...  0.924643
# 23  {'columntransformer__num_pipe__simpleimputer__...  0.922098
# 24  {'columntransformer__num_pipe__simpleimputer__...  0.924673
# 25  {'columntransformer__num_pipe__simpleimputer__...  0.916922
# 26  {'columntransformer__num_pipe__simpleimputer__...  0.926360
# 27  {'columntransformer__num_pipe__simpleimputer__...  0.924640
# 28  {'columntransformer__num_pipe__simpleimputer__...  0.912688
# 29  {'columntransformer__num_pipe__simpleimputer__...  0.926386
# 30  {'columntransformer__num_pipe__simpleimputer__...  0.917820
# 31  {'columntransformer__num_pipe__simpleimputer__...  0.917820
# 32  {'columntransformer__num_pipe__simpleimputer__...  0.917820
# 33  {'columntransformer__num_pipe__simpleimputer__...  0.917820
# 34  {'columntransformer__num_pipe__simpleimputer__...  0.917820
# 35  {'columntransformer__num_pipe__simpleimputer__...  0.922090
# 36  {'columntransformer__num_pipe__simpleimputer__...  0.925509
# 37  {'columntransformer__num_pipe__simpleimputer__...  0.919530
# 38  {'columntransformer__num_pipe__simpleimputer__...  0.921243
# 39  {'columntransformer__num_pipe__simpleimputer__...  0.924676
# 40  {'columntransformer__num_pipe__simpleimputer__...  0.922938
# 41  {'columntransformer__num_pipe__simpleimputer__...  0.927222
# 42  {'columntransformer__num_pipe__simpleimputer__...  0.927215
# 43  {'columntransformer__num_pipe__simpleimputer__...  0.921243
# 44  {'columntransformer__num_pipe__simpleimputer__...  0.924673
# 45  {'columntransformer__num_pipe__simpleimputer__...  0.916063
# 46  {'columntransformer__num_pipe__simpleimputer__...  0.927215
# 47  {'columntransformer__num_pipe__simpleimputer__...  0.924640
# 48  {'columntransformer__num_pipe__simpleimputer__...  0.919526
# 49  {'columntransformer__num_pipe__simpleimputer__...  0.923818
# 50  {'columntransformer__num_pipe__simpleimputer__...  0.914369
# 51  {'columntransformer__num_pipe__simpleimputer__...  0.921228
# 52  {'columntransformer__num_pipe__simpleimputer__...  0.926360
# 53  {'columntransformer__num_pipe__simpleimputer__...  0.922956
# 54  {'columntransformer__num_pipe__simpleimputer__...  0.924673
# 55  {'columntransformer__num_pipe__simpleimputer__...  0.920344
# 56  {'columntransformer__num_pipe__simpleimputer__...  0.925502
# 57  {'columntransformer__num_pipe__simpleimputer__...  0.925502
# 58  {'columntransformer__num_pipe__simpleimputer__...  0.915260
# 59  {'columntransformer__num_pipe__simpleimputer__...  0.925531
#
# Best KNeighborsClassifier Parameters:
# columntransformer__num_pipe__simpleimputer__strategy: mean
# decisiontreeclassifier__max_depth: 6
# decisiontreeclassifier__min_samples_leaf: 5
#
# Best Score: 0.9289314405194233

# %% [markdown]
# >> **conclusion:**
#
# Best KNeighborsClassifier Parameters:
#
# columntransformer__num_pipe__simpleimputer__strategy: median
#
# decisiontreeclassifier__max_depth: 6
#
# decisiontreeclassifier__min_samples_leaf: 5
#
# Best Score: 0.9289314405194233

# %%
# Error analysos
# test accuracy
accuracy_score(model_dtree.predict(X_test), y_test)
# Out:
# 0.9315068493150684

# %%
# read general_test to CSV in Colab

from google.colab import drive
from google.colab import files

# Mount your Google Drive
drive.mount('/content/drive')

# Specify the path to the CSV file on Google Drive
file_path = "/content/drive/My Drive/Colab Notebooks/test_set_classification.csv"
# this vaule looks pretty good and now test on the test set
general_test = pd.read_csv(file_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
general_test.head()
# Out:
#      Id  LotArea  LotFrontage  TotalBsmtSF  BedroomAbvGr  Fireplaces  \
# 0  1461    11622         80.0        882.0             2           0
# 1  1462    14267         81.0       1329.0             3           0
# 2  1463    13830         74.0        928.0             3           1
# 3  1464     9978         78.0        926.0             3           1
# 4  1465     5005         43.0       1280.0             2           0
#
#    PoolArea  GarageCars  WoodDeckSF  ScreenPorch  ... GarageType GarageFinish  \
# 0         0         1.0         140          120  ...     Attchd          Unf
# 1         0         1.0         393            0  ...     Attchd          Unf
# 2         0         2.0         212            0  ...     Attchd          Fin
# 3         0         2.0         360            0  ...     Attchd          Fin
# 4         0         2.0           0          144  ...     Attchd          RFn
#
#   GarageQual GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType  \
# 0         TA         TA          Y    NaN  MnPrv         NaN       WD
# 1         TA         TA          Y    NaN    NaN        Gar2       WD
# 2         TA         TA          Y    NaN  MnPrv         NaN       WD
# 3         TA         TA          Y    NaN    NaN         NaN       WD
# 4         TA         TA          Y    NaN    NaN         NaN       WD
#
#   SaleCondition
# 0        Normal
# 1        Normal
# 2        Normal
# 3        Normal
# 4        Normal
#
# [5 rows x 80 columns]

# %%
pred_dtree = model_dtree.predict(general_test)

# %%
pred_dtree
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
# save results
predictions = pd.DataFrame({"Id": general_test["Id"], "Expensive": pred_dtree})
predictions.to_csv("predictions_dtree.csv", index=False)

# %%
len(predictions)
# Out:
# 1459

# %%
# Upload the CSV to Google Drive
files.download('predictions_dtree.csv')

# %% [markdown]
# ### **Step 2-2. Modelling (RandomForestClassifier)**
