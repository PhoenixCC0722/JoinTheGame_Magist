# %% [markdown]
# <a href="https://colab.research.google.com/github/PhoenixCC0722/Journey_to_become_DataScientist/blob/main/Kopie_von_Copy_3_1_6_cateory_creation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Searching for the category**

# %%
import pandas as pd

# %%
# products_cl.csv
url = "https://drive.google.com/file/d/1s7Lai4NSlsYjGEPg1QSOUJobNYVsZBOJ/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
products_cl = pd.read_csv(path)

# %%
product_category_df = products_cl.copy()

# %%
product_category_df.head()
# Out:
#        sku                                           name  \
# 0  RAI0007              Silver Rain Design mStand Support
# 1  APP0023              Apple Mac Keyboard Keypad Spanish
# 2  APP0025               Mighty Mouse Apple Mouse for Mac
# 3  APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4  KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
#
#                                                 desc  price  in_stock  \
# 0       Aluminum support compatible with all MacBook  59.99         1
# 1          USB ultrathin keyboard Apple Mac Spanish.  59.00         0
# 2                             mouse Apple USB cable.  59.00         0
# 3              IPhone dock and USB Cable Apple iPod.  25.00         0
# 4  2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99         1
#
#        type
# 0      8696
# 1  13855401
# 2      1387
# 3      1230
# 4      1364

# %% [markdown]
# # 4.  [BONUS] Using type to create categories

# %% [markdown]
# There could be another way to create categories, but this one you'll have to explore this one alone.
#
# We have the mysterious column type in the products table. This could potentially be ready-made categories labelled with numbers instead of words. Let's investigate.

# %%
category_type_df = products_cl.copy()

# %% [markdown]
# Here are the types that have the most products.

# %%
category_type_df.groupby("type").count().nlargest(10, "sku")
# Out:
#            sku  name  desc  price  in_stock
# type
# 11865403  1057  1057  1057   1057      1057
# 12175397   939   939   939    939       939
# 1298       783   783   783    783       783
# 11935397   562   562   562    562       562
# 11905404   454   454   454    454       454
# 1282       373   373   373    373       373
# 12635403   362   362   362    362       362
# 13835403   269   269   269    269       269
# 5,74E+15   247   247   247    247       247
# 1364       216   216   216    216       216

# %% [markdown]
# Let's have a look at the first type to see if we can make categories from this column.

# %%
category_type_df.loc[category_type_df["type"] == "11865403"].sample(10)
# Out:
#           sku                                               name  \
# 8207  JMO0103   Just Mobile Tenc iPhone Case X Matte Transparent
# 5459  GRT0449  Griffin Survivor iPhone Case Journey 8 Plus / ...
# 8751  APP2560              Apple iPhone Leather Case Cover Red X
# 9530  MOS0243                Moshi iPhone Case SenseCover X Rosa
# 7799  AP20208  Second hand - Apple Leather Case Cover iPhone ...
# 4621  OTT0143  Otterbox Clearly Protected gel Case iPhone 6 /...
# 1161  OTT0054              Otterbox Defender Case Black iPhone 6
# 1369  MOS0145                    Moshi iGlaze iPhone 6 Plus Blue
# 2547  APP1137    Case Apple iPhone 6 / 6S Gray Pink Leather Case
# 5775  MOP0093  Hold Force Base Case Mophie iPhone Case 7 Plus...
#
#                                                    desc  price  in_stock  \
# 8207   Polycarbonate shell with self-heal for iPhone X.  24.99         1
# 5459  rugged case with shock dispersion system for i...  29.99         0
# 8751                        Leather case Apple official  59.00         0
# 9530  Moshi flip cover with activation function and ...  50.00         1
# 7799  Reconditioned ultrathin leather case and micro...  59.00         0
# 4621  transparent cover and a flexible piece TPU for...  19.99         1
# 1161                    Ultra Rugged Case for iPhone 6.  49.99         0
# 1369  Rigid shell shock protection and rasguÌ ± os f...  35.00         0
# 2547  ultrathin leather case and microfiber premium ...  55.00         0
# 5775  Case Ultra Thin magnetic plate on the back to ...  39.95         1
#
#           type
# 8207  11865403
# 5459  11865403
# 8751  11865403
# 9530  11865403
# 7799  11865403
# 4621  11865403
# 1161  11865403
# 1369  11865403
# 2547  11865403
# 5775  11865403

# %% [markdown]
# I wonder how many types account for most of our products?

# %%
n = 30
print(f"With the {n} largest types, we account for {((category_type_df.groupby('type').count().nlargest(n, 'sku')['sku'].sum()) / (category_type_df.shape[0]) * 100).round(2)}% of all products.")
# Out:
# With the 30 largest types, we account for 78.4% of all products.

# %%
n = 20
print(f"With the {n} largest types, we account for {((category_type_df.groupby('type').count().nlargest(n, 'sku')['sku'].sum()) / (category_type_df.shape[0]) * 100).round(2)}% of all products.")
# Out:
# With the 20 largest types, we account for 68.94% of all products.

# %%
n = 25
print(f"With the {n} largest types, we account for {((category_type_df.groupby('type').count().nlargest(n, 'sku')['sku'].sum()) / (category_type_df.shape[0]) * 100).round(2)}% of all products.")
# Out:
# With the 25 largest types, we account for 74.32% of all products.

# %% [markdown]
# Looks like we can simply investigate 30 types and set the categories, then the remaining 20% of products can have the category other.
#
# Use the skills you learnt above to change the category for each type.

# %% [markdown]
# ## Now find out the top 30 largest types and loop inside in the 'name' column to find out the most representative keywords of each category.

# %% [markdown]
# Try first with the top 1st

# %%
# here are the types that have the most products, check the first 30 types.
category_type_df.groupby("type").count().nlargest(30, "sku")
# Out:
#            sku  name  desc  price  in_stock
# type
# 11865403  1057  1057  1057   1057      1057
# 12175397   939   939   939    939       939
# 1298       783   783   783    783       783
# 11935397   562   562   562    562       562
# 11905404   454   454   454    454       454
# 1282       373   373   373    373       373
# 12635403   362   362   362    362       362
# 13835403   269   269   269    269       269
# 5,74E+15   247   247   247    247       247
# 1364       216   216   216    216       216
# 12585395   190   190   190    190       190
# 1296       187   187   187    187       187
# 1325       183   183   183    183       183
# 5384       178   178   178    178       178
# 1433       171   171   171    171       171
# 12215397   170   170   170    170       170
# 5398       159   159   159    159       159
# 1,02E+12   130   130   130    130       130
# 1,44E+11   129   129   129    129       129
# 57445397   129   129   129    129       129
# 1334       115   115   115    115       115
# 2158       107   107   107    107       107
# 2449       107   107   107    107       107
# 12655397   105   105   105    105       105
# 1229       104   104   104    104       104
# 12995397    95    95    95     95        95
# 1515        85    85    85     85        85
# 13615399    78    78    78     78        78
# 13555403    75    75    75     75        75
# 1405        75    75    75     75        75

# %%
category_type_df.type.iloc[1]
# Out:
# '13855401'

# %%
category_type_df.loc[category_type_df["type"] == "11865403"].sample(10)
# Out:
#             sku                                               name  \
# 8872    NTE0127  NewerTech NuGuard KX X-treme iPhone Case 8 Plu...
# 5229    APP1696    Leather Case Cover Apple iPhone 7 Plus Blue Sea
# 8248    SPE0208           Presidio Speck Case iPhone X Transparent
# 1916    HIC0018  Hitcase PRO lens cover submersible support iPh...
# 9725    ICA0113           Incase Frame Bumper Case iPhone X Silver
# 5202    APP1680           Apple iPhone Silicone Case Cover 7 Stone
# 5113    UAG0047  Urban Armor Gear Plasma iPhone Case 7 Black / ...
# 9435  APP1152-A  Open - Case Apple iPhone 6 Plus / 6s Plus Sili...
# 8907    OTT0173         OtterBox Defender Case iPhone 8/7 / 6s / 6
# 8017  MIN0004-A  Open - Minibatt wireless battery pack M1 for i...
#
#                                                    desc  price  in_stock  \
# 8872  Protective cover for massive drops NuGuard KX ...  60.99         0
# 5229  ultrathin leather case and microfiber premium ...  59.00         0
# 8248  protective case with anti-impact polycarbonate...  24.95         1
# 1916  waterproof case resistant to extreme condition...  99.99         0
# 9725  Transparent cover to protect the iPhone X with...  29.99         1
# 5202  Ultrathin silicone case and microfiber premium...  39.00         0
# 5113  Cover with military certificate falls and anti...  29.95         0
# 9435  Ultrathin silicone case and microfiber premium...  45.00         0
# 8907  Extra strong triple layer cover for your iPhon...  49.99         1
# 8017  Reconditioned cover M1 (accepts wireless charg...  79.90         0
#
#           type
# 8872  11865403
# 5229  11865403
# 8248  11865403
# 1916  11865403
# 9725  11865403
# 5202  11865403
# 5113  11865403
# 9435  11865403
# 8907  11865403
# 8017  11865403

# %% [markdown]
# ## Now, we should loop the finding Keywords function inside of the top 30 types, in each time, we go throw in the 'name' column and find out the most frequent words and regard it as the category name. Then put it into the new column 'category_name'

# %% [markdown]
# How to realize this function?

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
#	type – a numerical code for product type
category_top30_types_df = category_type_df.groupby("type").count().nlargest(30, "sku").reset_index()
category_top30_types_df.info()
category_top30_types_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   type      30 non-null     object
#  1   sku       30 non-null     int64
#  2   name      30 non-null     int64
#  3   desc      30 non-null     int64
#  4   price     30 non-null     int64
#  5   in_stock  30 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.5+ KB
#        type   sku  name  desc  price  in_stock
# 0  11865403  1057  1057  1057   1057      1057
# 1  12175397   939   939   939    939       939
# 2      1298   783   783   783    783       783
# 3  11935397   562   562   562    562       562
# 4  11905404   454   454   454    454       454

# %%
category_name = {}
top_N = 3
for i in range(len(category_top30_types_df)):
    num = category_top30_types_df.type.iloc[i]
    category_type_df_i = category_type_df.loc[category_type_df["type"] == num]
    category_type_df_i_copy = category_type_df_i.copy()
    category_type_df_i_copy["name_rep"] = category_type_df_i_copy.name.str.lower().str.replace('\W', ' ', regex=True)
    category_type_df_i_copy['tok'] = category_type_df_i_copy.name_rep.apply(nltk.tokenize.word_tokenize)
    words = category_type_df_i_copy.tok.tolist()  # this is a list of lists
    words = [word for sublist in words for word in sublist]  # flatten the list of lists
    word_dist = nltk.FreqDist(words)
    rslt = pd.DataFrame(word_dist.most_common(top_N), columns=['Word', 'Frequency'])
    top_3_words = word_dist.most_common(3)
    top_3_words_str = [word for word, freq in top_3_words]
    category_i = ' '.join(top_3_words_str)
    # Store results for each category separately
    category_name[num] = {'rslt': rslt, 'names': category_i} # dictionary

# %%
# Initialize an empty list to store data for each category
data = []

# Iterate through each category in the category_name dictionary
for category_id, values in category_name.items():
    category_data = {}
    category_data['type'] = category_id  # Assign the category ID

    # Extract the 'rslt' and 'names' values from the dictionary
    rslt_df = values['rslt']
    category_data['Word'] = ', '.join(rslt_df['Word'].astype(str).tolist())  # Convert Word column to comma-separated string
    category_data['Frequency'] = ', '.join(rslt_df['Frequency'].astype(str).tolist())  # Convert Frequency column to comma-separated string
    category_data['category_names'] = values['names']  # Assign the 'names' value

    # Append the category data to the list
    data.append(category_data)

# Create a DataFrame from the list of category data
result_df = pd.DataFrame(data)
# Display the DataFrame
#print(result_df)

# %%
result_df
# Out:
#         type                           Word        Frequency  \
# 0   11865403             iphone, case, plus  1047, 1045, 486
# 1   12175397             synology, nas, ram    582, 560, 504
# 2       1298               open, pro, black    763, 147, 144
# 3   11935397                  usb, 3, drive    351, 341, 305
# 4   11905404             iphone, white, and       79, 77, 74
# 5       1282               apple, core, ram    373, 292, 279
# 6   12635403              ipad, case, apple    363, 308, 145
# 7   13835403              macbook, case, 13    271, 205, 164
# 8   5,74E+15                apple, imac, 27    248, 247, 247
# 9       1364              memory, dimm, mac    214, 214, 213
# 10  12585395                usb, c, adapter     206, 131, 95
# 11      1296              monitor, hdmi, 27      180, 61, 55
# 12      1325                 cable, usb, to     137, 101, 70
# 13      5384  headphones, wireless, headset      102, 65, 59
# 14      1433            kit, ssd, expansion    181, 156, 153
# 15  12215397                  ssd, owc, pro      168, 84, 71
# 16      5398      speaker, bluetooth, black      133, 78, 57
# 17  1,02E+12            pro, apple, macbook    168, 132, 130
# 18  1,44E+11           repair, iphone, ipad      127, 77, 44
# 19  57445397                card, memory, s       59, 56, 56
# 20      1334                    link, d, wi       80, 56, 35
# 21      2158            pro, apple, macbook    156, 107, 107
# 22      2449             apple, strap, 42mm      107, 91, 69
# 23  12655397                hard, 35, drive       67, 66, 66
# 24      1229         pointer, stylus, wacom       48, 46, 42
# 25  12995397            3, usb, thunderbolt       55, 46, 38
# 26      1515         battery, external, usb       73, 38, 31
# 27  13615399           charger, belkin, car       45, 34, 29
# 28  13555403           iphone, protector, 6       74, 56, 49
# 29      1405          wacom, intuos, tablet       70, 46, 37
#
#                  category_names
# 0              iphone case plus
# 1              synology nas ram
# 2                open pro black
# 3                   usb 3 drive
# 4              iphone white and
# 5                apple core ram
# 6               ipad case apple
# 7               macbook case 13
# 8                 apple imac 27
# 9               memory dimm mac
# 10                usb c adapter
# 11              monitor hdmi 27
# 12                 cable usb to
# 13  headphones wireless headset
# 14            kit ssd expansion
# 15                  ssd owc pro
# 16      speaker bluetooth black
# 17            pro apple macbook
# 18           repair iphone ipad
# 19                card memory s
# 20                    link d wi
# 21            pro apple macbook
# 22             apple strap 42mm
# 23                hard 35 drive
# 24         pointer stylus wacom
# 25            3 usb thunderbolt
# 26         battery external usb
# 27           charger belkin car
# 28           iphone protector 6
# 29          wacom intuos tablet

# %% [markdown]
# Bug identified: type = 1298, 'open pro black' doesn't make any sense, have to recheck the 'name' and 'desc' again.
# Various stuff are there: Hard drive, Macbook Screen, Monitor... but why those complet irrelevant things have the same type code?

# %%
category_type_df.loc[category_type_df["type"] == "1298"].sample(10)
# Out:
#             sku                                               name  \
# 6301  APP0271-A  Open - Apple Wireless Keyboard Keyboard (OEM) Mac
# 3301  SAM0065-A                     (Open) Samsung 1TB SSD 850 PRO
# 2994  NTE0078-A  Open - NewerTech Maxpower Dual eSATA USB 3.0 P...
# 5051  APP1576-A  Open - Apple MacBook Air 13 "i7 22 Ghz | 8GB R...
# 1960  OND0067-A          (Open) Cable mini DisplayPort to HDMI 18m
# 6376  SAT0011-A  Open - Satechi Sonic Dual Conical Mac v2.0 Spe...
# 6212  OTT0099-A  Open - Clear Case OtterBox Symmetry iPhone 6 /...
# 6461  LGE0046-A  Open - LG 34UM68-P Monitor 34 "IPS HDMI Speake...
# 4731  SAN0095-A  (Open) SanDisk Ultra SDHC 32GB SD 80MB / s Cla...
# 7871  APP2073-A  Open - Apple MacBook Pro 13 "Core i5 23GHz | 8...
#
#                                                    desc    price  in_stock  \
# 6301  Ultrathin keyboard Apple Bluetooth Spanish (un...    79.00         0
# 3301                                  1TB SSD 3D VNAND.   479.99         0
# 2994  ESATA PCIe adapter card and USB 3.0 for Mac Pr...   149.99         0
# 5051  laptop MacBook Air 13 inch i7 22GHz 8GB RAM 12...  1219.00         0
# 1960    Cable Mini DisplayPort to HDMI (audio + video).    22.99         0
# 6376  Speakers matte finish sleek design and volume ...    39.99         0
# 6212  Protective housing with rear transparent and c...    34.99         0
# 6461  24 inch monitor IPS ultra-widescreen (21: 9) 9...   599.00         0
# 4731                     SDHC Memory Card 32GB 80MB / s    10.99         0
# 7871  MacBook reconditioned 13 inch i5 23GHz with 8G...  1505.59         0
#
#       type
# 6301  1298
# 3301  1298
# 2994  1298
# 5051  1298
# 1960  1298
# 6376  1298
# 6212  1298
# 6461  1298
# 4731  1298
# 7871  1298

# %% [markdown]
# And now just add the column 'Names' from DataFrame 'result_df' back to the original DataFrame 'category_type_df'

# %%
#Merge result_df with category_type_df using a left join on the 'Type' column
category_type_df_merge = category_type_df.merge(result_df[['type','category_names']],how='left',on='type')
# Fill missing values in the 'Names' column with 'others'
category_type_df_merge['category_names'].fillna('others', inplace=True)
category_type_df_merge.sample(10)
# Out:
#             sku                                               name  \
# 7843    POL0015              Polaroid ZINK Printing Pack 30 Sheets
# 8544    PAC2216  Synology DS718 + NAS Server | 16GB RAM | 4TB (...
# 645     SEA0061                  2TB Seagate SSHD Hybrid disc 35 "
# 633   OWC0088-2       Mac OWC Memory 8GB (2x4GB) 1333MHz DDR3 DIMM
# 9461  SYN0174-A      Open - Synology DS718 + NAS server Mac and PC
# 7754    BOS0055    Bose SoundLink Bluetooth Speaker Black Color II
# 949     PUR0120                 Puro Booklet Cover iPhone 6 Silver
# 1867    PIE0061                                   Piece LCD iPad 2
# 1682    APP0940  Apple MacBook Air 11 "i5 16 Ghz | 4GB RAM | 51...
# 917     WDT0251  Western Digital Green 5TB 35 "5400rpm hard dri...
#
#                                                    desc    price  in_stock  \
# 7843  Pack of 30 print sheets resistant material and...    19.00         0
# 8544  Scalable NAS server with transcoding 4K: 4-cor...   840.71         0
# 645   Hybrid Hard Drive Mac and PC + 8GB SSD 2TB 720...   121.00         0
# 633                  RAM 8GB (2x4GB) Mac Pro 2009/2010.    69.98         0
# 9461  Scalable NAS server refitted and transcoding 4...   459.99         0
# 7754  portable speaker with Bluetooth connection wat...   139.00         0
# 949   Case closed book card case for iPhone 6 47 inc...    19.99         0
# 1867                        LCD Replacement for iPad 2.    74.90         0
# 1682  laptop MacBook Air 11 inch i5 16 GHz 4GB 512GB...  1609.00         0
# 917   WD hard drives designed for desktop computers ...   237.00         0
#
#           type           category_names
# 7843  11905404         iphone white and
# 8544  12175397         synology nas ram
# 645   12655397            hard 35 drive
# 633       1364          memory dimm mac
# 9461  12175397         synology nas ram
# 7754      5398  speaker bluetooth black
# 949   11865403         iphone case plus
# 1867  21535407                   others
# 1682      1282           apple core ram
# 917   12655397            hard 35 drive

# %% [markdown]
# first drop all the 'others'(NaN), and then if two or more Produkt have the same the same category_names and then concencate them as one category, regardless of the Type code.
# Or should all the product with the 'case' Keyword also conducted as one category 'case'?
